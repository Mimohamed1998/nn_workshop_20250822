# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../src")

# %%
from matplotlib import pyplot as plt
from octave.tutorial import config, train_eval

# %%
cfg = config.Config()
train_losses, train_r2s, val_r2s = train_eval.train_and_eval(cfg)
# Out:
# Epoch 001: Train Loss = 0.5672 | Train R^2 = 0.7258 | Val R^2 = 0.7061
# Epoch 002: Train Loss = 0.3711 | Train R^2 = 0.7395 | Val R^2 = 0.7221
# Epoch 002: Train Loss = 0.3711 | Train R^2 = 0.7395 | Val R^2 = 0.7221
# Epoch 003: Train Loss = 0.3484 | Train R^2 = 0.7378 | Val R^2 = 0.7139
# Epoch 003: Train Loss = 0.3484 | Train R^2 = 0.7378 | Val R^2 = 0.7139
# Epoch 004: Train Loss = 0.3435 | Train R^2 = 0.7347 | Val R^2 = 0.7217
# Epoch 004: Train Loss = 0.3435 | Train R^2 = 0.7347 | Val R^2 = 0.7217
# Epoch 005: Train Loss = 0.3259 | Train R^2 = 0.7658 | Val R^2 = 0.7555
# Epoch 005: Train Loss = 0.3259 | Train R^2 = 0.7658 | Val R^2 = 0.7555
# Epoch 006: Train Loss = 0.3257 | Train R^2 = 0.7470 | Val R^2 = 0.7337
# Epoch 006: Train Loss = 0.3257 | Train R^2 = 0.7470 | Val R^2 = 0.7337
# Epoch 007: Train Loss = 0.3315 | Train R^2 = 0.7601 | Val R^2 = 0.7469
# Epoch 007: Train Loss = 0.3315 | Train R^2 = 0.7601 | Val R^2 = 0.7469
# Epoch 008: Train Loss = 0.3171 | Train R^2 = 0.7578 | Val R^2 = 0.7383
# Epoch 008: Train Loss = 0.3171 | Train R^2 = 0.7578 | Val R^2 = 0.7383
# Epoch 009: Train Loss = 0.3131 | Train R^2 = 0.7761 | Val R^2 = 0.7608
# Epoch 009: Train Loss = 0.3131 | Train R^2 = 0.7761 | Val R^2 = 0.7608
# Epoch 010: Train Loss = 0.3114 | Train R^2 = 0.7172 | Val R^2 = 0.7232
# Epoch 010: Train Loss = 0.3114 | Train R^2 = 0.7172 | Val R^2 = 0.7232
# Epoch 011: Train Loss = 0.3223 | Train R^2 = 0.7612 | Val R^2 = 0.7408
# Epoch 011: Train Loss = 0.3223 | Train R^2 = 0.7612 | Val R^2 = 0.7408
# Epoch 012: Train Loss = 0.3024 | Train R^2 = 0.7723 | Val R^2 = 0.7583
# Epoch 012: Train Loss = 0.3024 | Train R^2 = 0.7723 | Val R^2 = 0.7583
# Epoch 013: Train Loss = 0.2974 | Train R^2 = 0.7809 | Val R^2 = 0.7699
# Epoch 013: Train Loss = 0.2974 | Train R^2 = 0.7809 | Val R^2 = 0.7699
# Epoch 014: Train Loss = 0.3021 | Train R^2 = 0.7843 | Val R^2 = 0.7659
# Epoch 014: Train Loss = 0.3021 | Train R^2 = 0.7843 | Val R^2 = 0.7659
# Epoch 015: Train Loss = 0.3116 | Train R^2 = 0.7775 | Val R^2 = 0.7648
# Epoch 015: Train Loss = 0.3116 | Train R^2 = 0.7775 | Val R^2 = 0.7648
# Epoch 016: Train Loss = 0.3017 | Train R^2 = 0.7934 | Val R^2 = 0.7767
# Epoch 016: Train Loss = 0.3017 | Train R^2 = 0.7934 | Val R^2 = 0.7767
# Epoch 017: Train Loss = 0.2960 | Train R^2 = 0.7916 | Val R^2 = 0.7739
# Epoch 017: Train Loss = 0.2960 | Train R^2 = 0.7916 | Val R^2 = 0.7739
# Epoch 018: Train Loss = 0.2872 | Train R^2 = 0.7936 | Val R^2 = 0.7713
# Epoch 018: Train Loss = 0.2872 | Train R^2 = 0.7936 | Val R^2 = 0.7713
# Epoch 019: Train Loss = 0.2892 | Train R^2 = 0.7971 | Val R^2 = 0.7779
# Epoch 019: Train Loss = 0.2892 | Train R^2 = 0.7971 | Val R^2 = 0.7779
# Epoch 020: Train Loss = 0.2824 | Train R^2 = 0.7869 | Val R^2 = 0.7687
# Epoch 020: Train Loss = 0.2824 | Train R^2 = 0.7869 | Val R^2 = 0.7687
# Epoch 021: Train Loss = 0.2835 | Train R^2 = 0.7828 | Val R^2 = 0.7562
# Epoch 021: Train Loss = 0.2835 | Train R^2 = 0.7828 | Val R^2 = 0.7562
# Epoch 022: Train Loss = 0.2800 | Train R^2 = 0.7763 | Val R^2 = 0.7554
# Epoch 022: Train Loss = 0.2800 | Train R^2 = 0.7763 | Val R^2 = 0.7554
# Epoch 023: Train Loss = 0.2794 | Train R^2 = 0.7905 | Val R^2 = 0.7696
# Epoch 023: Train Loss = 0.2794 | Train R^2 = 0.7905 | Val R^2 = 0.7696
# Epoch 024: Train Loss = 0.2804 | Train R^2 = 0.7963 | Val R^2 = 0.7793
# Epoch 024: Train Loss = 0.2804 | Train R^2 = 0.7963 | Val R^2 = 0.7793
# Epoch 025: Train Loss = 0.2732 | Train R^2 = 0.8049 | Val R^2 = 0.7808
# Epoch 025: Train Loss = 0.2732 | Train R^2 = 0.8049 | Val R^2 = 0.7808

# %%
plt.plot(train_losses, label="Train Loss")
plt.plot(train_r2s, label="Train R2")
plt.plot(val_r2s, label="Validation R2")
plt.xlabel("Epoch")
plt.ylabel("Score / Loss")
plt.legend()
plt.title("Training Progress")
plt.show()
